# %%
import spacy
import pandas as pd
import numpy as np

from collections import Counter
from string import punctuation
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Embedding, Flatten

# %%
data=pd.read_csv(r"C:\Users\HP\Downloads\data.csv")
data=data.astype(str)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
result = []
pos_tag = ['PROPN','NOUN'] 

for text in data['content']:
    doc = nlp(text.lower())
    for token in doc:
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        if(token.pos_ in pos_tag):
            result.append(token.text)

# %%
cryptowords=pd.read_csv(r"C:\Users\HP\Downloads\term_abb.csv")
cryptowords=cryptowords.astype(str)

# %%
comstring=" "
crypdic=[]
for ele in cryptowords['terms']:
     doc = nlp(ele.lower())
     for token in doc:
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        if(token.pos_ in pos_tag):
            crypdic.append(token.text)
            comstring+= " "+token.text

# %%
comstring
# Out:
# '  cash dash eos.io ethereum classic ethereum gridcoin coinye nano titcoin usd coin stablecoin tether vertcoin monero primecoin ripple bitcoin improvement proposal teller machine bitcoin enterprise ethereum alliance ethereum improvement proposal analysis convergence divergence proof burn proof developer analysis analysis time year date address application programming interface brute force attack bitcoin address format bc1 addresses developers hash acronym bit developers money laundering time time low coin offering dollar cost averaging finance ledger technology standard ethereum standard nft tokens exchange fund exchange product government currency dollar euro bounty millibitcoin btc pump dump scheme microbitcoin btc transaction person fear uncertainty joy customer lamborghini cryptocurrency term term losses onion router data crypto twitter'

# %%
(nlp(result[0])).similarity(nlp(comstring))
# Out:
# <ipython-input-8-e51f7cbc72c7>:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   (nlp(result[0])).similarity(nlp(comstring))
# 0.16227905818720917

# %%
# CrypRelWords=[]
# simcheckvals=[]
# for word in result:
#     simcheck=(nlp(word)).similarity(nlp(comstring))
#     simcheckvals.append(simcheck)
#     if(simcheck>=0.5):
#         print("A CRYPTO RELATED WORD\n")
#         CrypRelWord.append(word,simcheck)
        
#         print( word,+": "+simcheck*100)

# %%
# CrypRelWord2=[]
# simcheckvals2=[]

# avgsimval=0
# for word in result:
#     simval=0
#     for checkword in crypdic:
#         simcheck=(nlp(word)).similarity(nlp(checkword))
#         simval+=simcheck
#     avgsimval=simval/len(crypdic)    
#     simcheckvals2.append(avgsimval)
#     if(avgsimval>=0.6):
#         print("A CRYPTO RELATED WORD\n")
#         CrypRelWord2.append([word,avgsimval])
        
#         print( word+": "+str(avgsimval*100))
# Out:
# <ipython-input-10-2d51e1be1a4b>:8: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   simcheck=(nlp(word)).similarity(nlp(checkword))
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# template: 60.20171772696504
# A CRYPTO RELATED WORD
#
# pampu: 60.313934516743174
# A CRYPTO RELATED WORD
#
# omfg: 60.80932679298794
# A CRYPTO RELATED WORD
#
# friend: 60.46926138395994
# A CRYPTO RELATED WORD
#
# experience: 60.891599779701025
# A CRYPTO RELATED WORD
#
# sarcasm: 61.14706824846202
# A CRYPTO RELATED WORD
#
# lite: 60.41313828716007
# A CRYPTO RELATED WORD
#
# probability: 62.559078416593195
# A CRYPTO RELATED WORD
#
# sarcasm: 61.14706824846202
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# default: 60.150602767934856
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# volume: 63.62737796591671
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# enforcement: 61.89929135755268
# A CRYPTO RELATED WORD
#
# record: 62.05954180216424
# A CRYPTO RELATED WORD
#
# sarcasm: 61.14706824846202
# A CRYPTO RELATED WORD
#
# sale: 61.813735875667355
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# armchair: 62.270804791318525
# A CRYPTO RELATED WORD
#
# process: 61.82128794837396
# A CRYPTO RELATED WORD
#
# ondo: 62.109501757931206
# A CRYPTO RELATED WORD
#
# ondo: 62.109501757931206
# A CRYPTO RELATED WORD
#
# discord: 60.92929271768013
# A CRYPTO RELATED WORD
#
# crime: 60.36433764594188
# A CRYPTO RELATED WORD
#
# hardware: 60.292311539590685
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# hardware: 60.292311539590685
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# scale: 60.99404139282078
# A CRYPTO RELATED WORD
#
# discord: 60.92929271768013
# A CRYPTO RELATED WORD
#
# discord: 60.92929271768013
# A CRYPTO RELATED WORD
#
# process: 61.82128794837396
# A CRYPTO RELATED WORD
#
# contributor: 61.115606238190225
# A CRYPTO RELATED WORD
#
# discord: 60.92929271768013
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# graph: 60.44531503516398
# A CRYPTO RELATED WORD
#
# graph: 60.44531503516398
# A CRYPTO RELATED WORD
#
# graph: 60.44531503516398
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# audit: 61.03961633364891
# A CRYPTO RELATED WORD
#
# graph: 60.44531503516398
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# competitor: 62.07394309606453
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# sale: 61.813735875667355
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# crystallblockchain: 60.694261374528644
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# volume: 63.62737796591671
# A CRYPTO RELATED WORD
#
# currency: 61.277807285700725
# A CRYPTO RELATED WORD
#
# impact: 60.095137898139825
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# fatness: 62.09738524573854
# A CRYPTO RELATED WORD
#
# silence: 60.46059799442441
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# promotion: 60.60891402079894
# A CRYPTO RELATED WORD
#
# machine: 61.419968783492266
# A CRYPTO RELATED WORD
#
# process: 61.82128794837396
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# software: 61.00324511882662
# A CRYPTO RELATED WORD
#
# verification: 62.12264582177542
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# scale: 60.99404139282078
# A CRYPTO RELATED WORD
#
# site: 61.55539747980622
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# opinion: 61.33879438642478
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# incident: 60.460978909933935
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# opinion: 61.33879438642478
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# line: 63.008819479221756
# A CRYPTO RELATED WORD
#
# treausury: 60.55628655799976
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# exploitation: 61.27038971055807
# A CRYPTO RELATED WORD
#
# agreement: 60.10746548752165
# A CRYPTO RELATED WORD
#
# control: 63.56899008949857
# A CRYPTO RELATED WORD
#
# disclosure: 62.00572661928507
# A CRYPTO RELATED WORD
#
# blog: 60.95125189487841
# A CRYPTO RELATED WORD
#
# efficiency: 60.91380022808192
# A CRYPTO RELATED WORD
#
# knowledge: 60.453283643578146
# A CRYPTO RELATED WORD
#
# girl: 64.39780196904155
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# hierarchy: 61.041376899827945
# A CRYPTO RELATED WORD
#
# brain: 60.877358109288984
# A CRYPTO RELATED WORD
#
# scale: 60.99404139282078
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# mode: 62.185315109952896
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# volume: 63.62737796591671
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# benefit: 61.40045696754113
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# application: 60.89695937503787
# A CRYPTO RELATED WORD
#
# application: 60.89695937503787
# A CRYPTO RELATED WORD
#
# homepage: 60.158918024232335
# A CRYPTO RELATED WORD
#
# publicity: 61.195888810285396
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# type: 62.34590446632829
# A CRYPTO RELATED WORD
#
# list: 62.31930764220698
# A CRYPTO RELATED WORD
#
# activity: 61.75333352099509
# A CRYPTO RELATED WORD
#
# shardeum: 63.55929843167274
# A CRYPTO RELATED WORD
#
# line: 63.008819479221756
# A CRYPTO RELATED WORD
#
# shardeum: 63.55929843167274
# A CRYPTO RELATED WORD
#
# saylor: 61.055660496453356
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# billionaire: 62.491434169698614
# A CRYPTO RELATED WORD
#
# raydium: 60.060338225677214
# A CRYPTO RELATED WORD
#
# figure: 60.870994051276995
# A CRYPTO RELATED WORD
#
# loan: 60.932911027273164
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# drainage: 60.40368383675667
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# audit: 61.03961633364891
# A CRYPTO RELATED WORD
#
# audit: 61.03961633364891
# A CRYPTO RELATED WORD
#
# opinion: 61.33879438642478
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# signature: 63.06474806845973
# A CRYPTO RELATED WORD
#
# function: 61.00887882405828
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# function: 61.00887882405828
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# raydium: 60.060338225677214
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# volume: 63.62737796591671
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# body: 62.36895818990036
# A CRYPTO RELATED WORD
#
# friend: 60.46926138395994
# A CRYPTO RELATED WORD
#
# gotcha: 60.1005799356612
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# charity: 62.09021913580889
# A CRYPTO RELATED WORD
#
# function: 61.00887882405828
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# default: 60.150602767934856
# A CRYPTO RELATED WORD
#
# opinion: 61.33879438642478
# A CRYPTO RELATED WORD
#
# default: 60.150602767934856
# A CRYPTO RELATED WORD
#
# default: 60.150602767934856
# A CRYPTO RELATED WORD
#
# default: 60.150602767934856
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# scratch: 62.1111547242733
# A CRYPTO RELATED WORD
#
# charity: 62.09021913580889
# A CRYPTO RELATED WORD
#
# approval: 60.96103218068575
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# site: 61.55539747980622
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# knowledge: 60.453283643578146
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# approval: 60.96103218068575
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# efficiency: 60.91380022808192
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# place: 60.01253690224293
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# factor: 60.55535131009526
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# experience: 60.891599779701025
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# audit: 61.03961633364891
# A CRYPTO RELATED WORD
#
# process: 61.82128794837396
# A CRYPTO RELATED WORD
#
# platinum: 62.753089398892456
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# farm: 62.54817777879978
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# investigator: 61.01895965427689
# A CRYPTO RELATED WORD
#
# liquidator: 60.964131164491306
# A CRYPTO RELATED WORD
#
# liquidator: 60.964131164491306
# A CRYPTO RELATED WORD
#
# actor: 60.030919590349576
# A CRYPTO RELATED WORD
#
# audit: 61.03961633364891
# A CRYPTO RELATED WORD
#
# company: 61.03037654033797
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# list: 62.31930764220698
# A CRYPTO RELATED WORD
#
# audit: 61.03961633364891
# A CRYPTO RELATED WORD
#
# discord: 60.92929271768013
# A CRYPTO RELATED WORD
#
# audit: 61.03961633364891
# A CRYPTO RELATED WORD
#
# openness: 61.1675677124175
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# openness: 61.1675677124175
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# openness: 61.1675677124175
# A CRYPTO RELATED WORD
#
# immunefi: 60.5105131411484
# A CRYPTO RELATED WORD
#
# audit: 61.03961633364891
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# company: 61.03037654033797
# A CRYPTO RELATED WORD
#
# bottle: 61.63642949692626
# A CRYPTO RELATED WORD
#
# interface: 62.689438727390865
# A CRYPTO RELATED WORD
#
# interface: 62.689438727390865
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# investment: 62.47091428866723
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# place: 60.01253690224293
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# place: 60.01253690224293
# A CRYPTO RELATED WORD
#
# impact: 60.095137898139825
# A CRYPTO RELATED WORD
#
# script: 61.44052576880667
# A CRYPTO RELATED WORD
#
# management: 61.361697239592026
# A CRYPTO RELATED WORD
#
# farm: 62.54817777879978
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# longevity: 60.634698408839405
# A CRYPTO RELATED WORD
#
# place: 60.01253690224293
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# pill: 62.787241499530055
# A CRYPTO RELATED WORD
#
# certificate: 64.0035824138397
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# program: 62.45212056375813
# A CRYPTO RELATED WORD
#
# place: 60.01253690224293
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# liability: 61.21230272202849
# A CRYPTO RELATED WORD
#
# scope: 60.33763322918805
# A CRYPTO RELATED WORD
#
# crime: 60.36433764594188
# A CRYPTO RELATED WORD
#
# engine: 61.567905383018996
# A CRYPTO RELATED WORD
#
# income: 62.881470905452844
# A CRYPTO RELATED WORD
#
# summit: 61.299479997587206
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# path: 60.89752079914527
# A CRYPTO RELATED WORD
#
# income: 62.881470905452844
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# income: 62.881470905452844
# A CRYPTO RELATED WORD
#
# summit: 61.299479997587206
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# bottle: 61.63642949692626
# A CRYPTO RELATED WORD
#
# company: 61.03037654033797
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# friend: 60.46926138395994
# A CRYPTO RELATED WORD
#
# company: 61.03037654033797
# A CRYPTO RELATED WORD
#
# company: 61.03037654033797
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# discord: 60.92929271768013
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# coffin: 60.454976989879604
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# regulator: 61.057684077581875
# A CRYPTO RELATED WORD
#
# selection: 61.48324180149316
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# recommendation: 60.03676980035719
# A CRYPTO RELATED WORD
#
# control: 63.56899008949857
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# software: 61.00324511882662
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# vasp: 60.447820368140626
# A CRYPTO RELATED WORD
#
# vasp: 60.447820368140626
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# engine: 61.567905383018996
# A CRYPTO RELATED WORD
#
# scale: 60.99404139282078
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# path: 60.89752079914527
# A CRYPTO RELATED WORD
#
# path: 60.89752079914527
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# scale: 60.99404139282078
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# wave: 60.27874000635999
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# control: 63.56899008949857
# A CRYPTO RELATED WORD
#
# regime: 60.503320361139245
# A CRYPTO RELATED WORD
#
# character: 60.28145263753826
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# efficiency: 60.91380022808192
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# exploitation: 61.27038971055807
# A CRYPTO RELATED WORD
#
# gotcha: 60.1005799356612
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# arbitrage: 60.715619542172206
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# sender: 60.98228598660801
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# automation: 62.54661944720971
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# factor: 60.55535131009526
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# gold: 60.554693062868324
# A CRYPTO RELATED WORD
#
# pattern: 61.12002138895918
# A CRYPTO RELATED WORD
#
# application: 60.89695937503787
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# gold: 60.554693062868324
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# stability: 61.328647144033354
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# figure: 60.870994051276995
# A CRYPTO RELATED WORD
#
# figure: 60.870994051276995
# A CRYPTO RELATED WORD
#
# impact: 60.095137898139825
# A CRYPTO RELATED WORD
#
# peak: 60.610431773035245
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# software: 61.00324511882662
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# profanity: 64.46064459381212
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# graph: 60.44531503516398
# A CRYPTO RELATED WORD
#
# efficiency: 60.91380022808192
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# scale: 60.99404139282078
# A CRYPTO RELATED WORD
#
# defensibility: 60.19672272302701
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# path: 60.89752079914527
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# script: 61.44052576880667
# A CRYPTO RELATED WORD
#
# graph: 60.44531503516398
# A CRYPTO RELATED WORD
#
# unmarshal: 61.192266837164944
# A CRYPTO RELATED WORD
#
# company: 61.03037654033797
# A CRYPTO RELATED WORD
#
# graph: 60.44531503516398
# A CRYPTO RELATED WORD
#
# script: 61.44052576880667
# A CRYPTO RELATED WORD
#
# type: 62.34590446632829
# A CRYPTO RELATED WORD
#
# discord: 60.92929271768013
# A CRYPTO RELATED WORD
#
# exploitation: 61.27038971055807
# A CRYPTO RELATED WORD
#
# company: 61.03037654033797
# A CRYPTO RELATED WORD
#
# capital: 61.92498584826717
# A CRYPTO RELATED WORD
#
# system: 60.19720835465119
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# machine: 61.419968783492266
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# factor: 60.55535131009526
# A CRYPTO RELATED WORD
#
# machine: 61.419968783492266
# A CRYPTO RELATED WORD
#
# process: 61.82128794837396
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# volume: 63.62737796591671
# A CRYPTO RELATED WORD
#
# trade: 62.837800844654126
# A CRYPTO RELATED WORD
#
# trade: 62.837800844654126
# A CRYPTO RELATED WORD
#
# sport: 61.92660246090895
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# investment: 62.47091428866723
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# research: 61.03523167068546
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# project: 60.02495380145535
# A CRYPTO RELATED WORD
#
# place: 60.01253690224293
# A CRYPTO RELATED WORD
#
# calendar: 60.60022402705578
# A CRYPTO RELATED WORD
#
# list: 62.31930764220698
# A CRYPTO RELATED WORD
#
# process: 61.82128794837396
# A CRYPTO RELATED WORD
#
# frame: 62.456590391506204
# A CRYPTO RELATED WORD
#
# volume: 63.62737796591671
# A CRYPTO RELATED WORD
#
# emission: 61.61480687465654
# A CRYPTO RELATED WORD
#
# knowledge: 60.453283643578146
# A CRYPTO RELATED WORD
#
# selection: 61.48324180149316
# A CRYPTO RELATED WORD
#
# process: 61.82128794837396
# A CRYPTO RELATED WORD
#
# frame: 62.456590391506204
# A CRYPTO RELATED WORD
#
# product: 60.36844177840466
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# volume: 63.62737796591671
# A CRYPTO RELATED WORD
#
# experiment: 61.38984198185622
# A CRYPTO RELATED WORD
#
# blog: 60.95125189487841
# A CRYPTO RELATED WORD
#
# goodput: 60.75841427825453
# A CRYPTO RELATED WORD
#
# contract: 62.43103398206053
# A CRYPTO RELATED WORD
#
# coincidence: 60.059184440363765
# A CRYPTO RELATED WORD
#
# episode: 60.50350756113685
# A CRYPTO RELATED WORD
#
# frame: 62.456590391506204
# A CRYPTO RELATED WORD
#
# mode: 62.185315109952896
# A CRYPTO RELATED WORD
#
# issue: 60.50237831290984
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# defi: 61.38732645898154
# A CRYPTO RELATED WORD
#
# pool: 63.78522366405623
# A CRYPTO RELATED WORD
#
# liquidity: 61.37881273383906
# A CRYPTO RELATED WORD
#
# risk: 60.1263247387663
# A CRYPTO RELATED WORD
#
# dovs: 60.88833908436653
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-2d51e1be1a4b> in <module>
#       6     simval=0
#       7     for checkword in crypdic:
# ----> 8         simcheck=(nlp(word)).similarity(nlp(checkword))
#       9         simval+=simcheck
#      10     avgsimval=simval/len(crypdic)
#
# ~\anaconda3\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#    1018                 error_handler = proc.get_error_handler()
#    1019             try:
# -> 1020                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1021             except KeyError as e:
#    1022                 # This typically happens if a component is not initialized
#
# ~\anaconda3\lib\site-packages\spacy\pipeline\trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# ~\anaconda3\lib\site-packages\spacy\pipeline\transition_parser.pyx in spacy.pipeline.transition_parser.Parser.predict()
#
# ~\anaconda3\lib\site-packages\spacy\pipeline\transition_parser.pyx in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# ~\anaconda3\lib\site-packages\thinc\model.py in predict(self, X)
#     313         only the output, instead of the `(output, callback)` tuple.
#     314         """
# --> 315         return self._func(self, X, is_train=False)[0]
#     316
#     317     def finish_update(self, optimizer: Optimizer) -> None:
#
# ~\anaconda3\lib\site-packages\spacy\ml\tb_framework.py in forward(model, X, is_train)
#      31
#      32 def forward(model, X, is_train):
# ---> 33     step_model = ParserStepModel(
#      34         X,
#      35         model.layers,
#
# ~\anaconda3\lib\site-packages\spacy\ml\parser_model.pyx in spacy.ml.parser_model.ParserStepModel.__init__()
#
# ~\anaconda3\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\anaconda3\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      53     callbacks = []
#      54     for layer in model.layers:
# ---> 55         Y, inc_layer_grad = layer(X, is_train=is_train)
#      56         callbacks.append(inc_layer_grad)
#      57         X = Y
#
# ~\anaconda3\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\anaconda3\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      53     callbacks = []
#      54     for layer in model.layers:
# ---> 55         Y, inc_layer_grad = layer(X, is_train=is_train)
#      56         callbacks.append(inc_layer_grad)
#      57         X = Y
#
# ~\anaconda3\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\anaconda3\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      53     callbacks = []
#      54     for layer in model.layers:
# ---> 55         Y, inc_layer_grad = layer(X, is_train=is_train)
#      56         callbacks.append(inc_layer_grad)
#      57         X = Y
#
# ~\anaconda3\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\anaconda3\lib\site-packages\thinc\layers\with_array.py in forward(model, Xseq, is_train)
#      30 ) -> Tuple[SeqT, Callable]:
#      31     if isinstance(Xseq, Ragged):
# ---> 32         return cast(Tuple[SeqT, Callable], _ragged_forward(model, Xseq, is_train))
#      33     elif isinstance(Xseq, Padded):
#      34         return cast(Tuple[SeqT, Callable], _padded_forward(model, Xseq, is_train))
#
# ~\anaconda3\lib\site-packages\thinc\layers\with_array.py in _ragged_forward(model, Xr, is_train)
#      85 ) -> Tuple[Ragged, Callable]:
#      86     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 87     Y, get_dX = layer(Xr.dataXd, is_train)
#      88
#      89     def backprop(dYr: Ragged) -> Ragged:
#
# ~\anaconda3\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\anaconda3\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      53     callbacks = []
#      54     for layer in model.layers:
# ---> 55         Y, inc_layer_grad = layer(X, is_train=is_train)
#      56         callbacks.append(inc_layer_grad)
#      57         X = Y
#
# ~\anaconda3\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\anaconda3\lib\site-packages\thinc\layers\chain.py in forward(model, X, is_train)
#      53     callbacks = []
#      54     for layer in model.layers:
# ---> 55         Y, inc_layer_grad = layer(X, is_train=is_train)
#      56         callbacks.append(inc_layer_grad)
#      57         X = Y
#
# ~\anaconda3\lib\site-packages\thinc\model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~\anaconda3\lib\site-packages\thinc\layers\maxout.py in forward(model, X, is_train)
#      47     W = model.get_param("W")
#      48     W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 49     Y = model.ops.gemm(X, W, trans2=True)
#      50     Y += model.ops.reshape1f(b, nO * nP)
#      51     Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %%
 CrypRelWord3=[]
simcheckvals3=[]

#avgsimval=0
for word in result:
    #simval=0
    for checkword in crypdic:
        simcheck=(nlp(word)).similarity(nlp(checkword))
        #simval+=simcheck
    #avgsimval=simval/len(crypdic)    
    #simcheckvals3.append(simcheck)
        if(simcheck>0.8):
            print("A CRYPTO RELATED WORD\n")
            CrypRelWord2.append([word,simcheck])
        
            print( word+": "+str(simcheck*100))
        break
# Out:
# <ipython-input-15-ed3cdcad63ef>:8: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   simcheck=(nlp(word)).similarity(nlp(checkword))
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# cash: 100.0
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# law: 81.3187527466118
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# tax: 83.28175046238235
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# tax: 83.28175046238235
# A CRYPTO RELATED WORD
#
# space: 83.49025128181093
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# space: 83.49025128181093
# A CRYPTO RELATED WORD
#
# drama: 83.92899154557091
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# direction: 80.08270303552071
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# cash: 100.0
# A CRYPTO RELATED WORD
#
# economy: 80.71442589162736
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# correlation: 81.29282400104022
# A CRYPTO RELATED WORD
#
# drama: 83.92899154557091
# A CRYPTO RELATED WORD
#
# death: 81.91194119694786
# A CRYPTO RELATED WORD
#
# utility: 81.48667093321536
# A CRYPTO RELATED WORD
#
# death: 81.91194119694786
# A CRYPTO RELATED WORD
#
# regulation: 80.12876409797846
# A CRYPTO RELATED WORD
#
# regulation: 80.12876409797846
# A CRYPTO RELATED WORD
#
# drama: 83.92899154557091
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# space: 83.49025128181093
# A CRYPTO RELATED WORD
#
# direction: 80.08270303552071
# A CRYPTO RELATED WORD
#
# regulation: 80.12876409797846
# A CRYPTO RELATED WORD
#
# regulation: 80.12876409797846
# A CRYPTO RELATED WORD
#
# regulation: 80.12876409797846
# A CRYPTO RELATED WORD
#
# regulation: 80.12876409797846
# A CRYPTO RELATED WORD
#
# space: 83.49025128181093
# A CRYPTO RELATED WORD
#
# brain: 83.7829367804749
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# space: 83.49025128181093
# A CRYPTO RELATED WORD
#
# utility: 81.48667093321536
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# direction: 80.08270303552071
# A CRYPTO RELATED WORD
#
# flight: 85.84032276465221
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# cash: 100.0
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# death: 81.91194119694786
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# policy: 80.84285889559047
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# cash: 100.0
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# cash: 100.0
# A CRYPTO RELATED WORD
#
# ignorance: 83.11294874597608
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# humanity: 80.61162700745852
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# revenue: 81.60334186287885
# A CRYPTO RELATED WORD
#
# liability: 80.83937027861204
# A CRYPTO RELATED WORD
#
# law: 81.3187527466118
# A CRYPTO RELATED WORD
#
# space: 83.49025128181093
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# economy: 80.71442589162736
# A CRYPTO RELATED WORD
#
# space: 83.49025128181093
# A CRYPTO RELATED WORD
#
# direction: 80.08270303552071
# A CRYPTO RELATED WORD
#
# cash: 100.0
# A CRYPTO RELATED WORD
#
# cash: 100.0
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# implementation: 81.48570065520425
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# implementation: 81.48570065520425
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# dominance: 82.77285494735204
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# law: 81.3187527466118
# A CRYPTO RELATED WORD
#
# implementation: 81.48570065520425
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# revenue: 81.60334186287885
# A CRYPTO RELATED WORD
#
# utility: 81.48667093321536
# A CRYPTO RELATED WORD
#
# liqudiity: 82.28791333926067
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# risk: 82.20226376692227
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# gas: 83.56484540676176
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# inflation: 81.68198111332995
# A CRYPTO RELATED WORD
#
# discretion: 81.55658946208956
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# discretion: 81.55658946208956
# A CRYPTO RELATED WORD
#
# economy: 80.71442589162736
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# policy: 80.84285889559047
# A CRYPTO RELATED WORD
#
# stability: 82.83986814329242
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
# A CRYPTO RELATED WORD
#
# market: 81.06572015817139
# A CRYPTO RELATED WORD
#
# money: 83.86389773042877
